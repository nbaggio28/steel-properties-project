# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
steel_df = pd.read_csv("../data/Steel- Property and Composition (Carbon Steel).csv", encoding="windows-1253")

# %%
steel_df.head(10)
# Out:
#   SAE Grade  Conditions  UTS (MPa)  UTS (Ksi)  YS (MPa) YS (ksi)  \
# 0      1006  Hot rolled        295         43       165       24
# 1      1006  Cold drawn        330         48       285       41
# 2      1008  Hot rolled        305         44       170     24.5
# 3      1008  Cold drawn        340         49       285       42
# 4      1010  Hot rolled        325         47       180       26
# 5      1010  Cold drawn        365         53       305       44
# 6      1012  Hot rolled        330         48       185       27
# 7      1012  Cold drawn        370         54       310       45
# 8      1015  Hot rolled        345         50       190       28
# 9      1015  Cold drawn        385         56       325       47
#
#    Elongation (%) Reduction (%) Hardness (HB)  C (Min)  ...  Si (Min)  \
# 0            30.0            55            86      NaN  ...       NaN
# 1            20.0            45            95      NaN  ...       NaN
# ...

# %%
steel_df['S(Max)']
# Out:
# 0      0.050
# 1      0.050
# 2      0.050
# 3      0.050
# 4      0.050
#        ...
# 185    0.040
# 186    0.040
# 187    0.040
# 188    0.025
# 189    0.025
# Name: S(Max), Length: 190, dtype: float64

# %%
steel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SAE Grade       190 non-null    object
#  1   Conditions      190 non-null    object
#  2   UTS (MPa)       190 non-null    int64
#  3   UTS (Ksi)       190 non-null    int64
#  4   YS (MPa)        190 non-null    int64
#  5   YS (ksi)        190 non-null    object
#  6   Elongation (%)  190 non-null    float64
#  7   Reduction (%)   190 non-null    object
#  8   Hardness (HB)   190 non-null    object
#  9   C (Min)         178 non-null    float64
#  10  C (Max)         190 non-null    float64
#  11  Mn (Min)        190 non-null    float64
#  12  Mn (Max)        190 non-null    float64
#  13  P (Min)         3 non-null      object
#  14  P (Max)         190 non-null    float64
#  15  S (Min)         28 non-null     float64
#  16  S(Max)          190 non-null    float64
# ...

# %%
steel_df["Conditions"].info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/nic/daimil10/assignments/steel-properties-project/notebooks/steel-properties.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/nic/daimil10/assignments/steel-properties-project/notebooks/steel-properties.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> steel_df["Conditions"].info()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5487, in NDFrame.__getattr__(self, name)
#    5480 if (
#    5481     name not in self._internal_names_set
#    5482     and name not in self._metadata
#    5483     and name not in self._accessors
#    5484     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5485 ):
#    5486     return self[name]
# -> 5487 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
steel_df.describe()
# Out:
#          UTS (MPa)    UTS (Ksi)     YS (MPa)  Elongation (%)     C (Min)  \
# count   190.000000   190.000000   190.000000      190.000000  178.000000
# mean    630.326316   165.973684   452.368421       16.925789    0.375225
# std     205.887905   647.779205   200.220490        6.113167    0.190904
# min     116.000000    43.000000   165.000000       10.000000    0.080000
# 25%     498.750000    74.000000   325.000000       12.000000    0.200000
# 50%     622.500000    91.000000   415.000000       15.000000    0.380000
# 75%     701.250000   102.000000   530.000000       21.775000    0.480000
# max    1310.000000  7175.000000  1215.000000       32.500000    0.900000
#
#           C (Max)    Mn (Min)    Mn (Max)     P (Max)    S (Min)  ...  \
# count  190.000000  190.000000  190.000000  190.000000  28.000000  ...
# mean     0.422368    0.682211    0.947737    0.043105   0.112857  ...
# std      0.221142    0.320187    0.351414    0.025283   0.072052  ...
# ...

# %% [markdown]
# ## Ideas
# - correlation between UTS, YS, conditions, and C (Max)
# - can you predict steel grade based on UTS, YS and C (Max)
# -
# - Strongest steel?
# - Most elastic?

# %%
steel_df = steel_df.rename(columns={"UTS (PSI)" :"Tensile Strength (PSI)", "YS (ksi)": "Yield Strength (PSI)" })
steel_df.head()
# Out:
#   SAE Grade  Conditions  UTS (MPa)  UTS (Ksi)  YS (MPa) Yield Strength (PSI)  \
# 0      1006  Hot rolled        295         43       165                   24
# 1      1006  Cold drawn        330         48       285                   41
# 2      1008  Hot rolled        305         44       170                 24.5
# 3      1008  Cold drawn        340         49       285                   42
# 4      1010  Hot rolled        325         47       180                   26
#
#    Elongation (%) Reduction (%) Hardness (HB)  C (Min)  ...  Si (Min)  \
# 0            30.0            55            86      NaN  ...       NaN
# 1            20.0            45            95      NaN  ...       NaN
# 2            30.0            55            86      NaN  ...       NaN
# 3            20.0            45            95      NaN  ...       NaN
# 4            28.0            50            95     0.08  ...       NaN
#
#    Si (Max)  Ni (Min) Ni (Max)  Cr (Min)  Cr (Max)  Mo (Min)  Mo (Max)  \
# ...

# %%
steel_df_sorted = steel_df.drop(
    columns={
        "C (Min)", "Si (Min)",
        "Si (Max)", "Ni (Min)",
        "Ni (Max)", "P (Min)",
        "P (Max)", "S (Min)",
        "S(Max)", "Cr (Min)",
        "Cr (Max)", "Mo (Min)",
        "Mo (Max)", "Ti (Min)",
        "Ti (Max)", "Mn (Min)",
        "Mn (Max)", "UTS (MPa)",
        "YS (MPa)"
        }, index={134})

# %%
sns.pairplot(steel_df_sorted)

# %%
steel_df_sorted["Yield Strength (PSI)"] = steel_df_sorted["Yield Strength (PSI)"].astype('float64')

# %%
steel_df_sorted = steel_df_sorted.drop(index={188,189})
# .value_counts(ascending=False)

# %%
steel_df_sorted["Reduction (%)"] = steel_df_sorted["Reduction (%)"].str.replace(",",".").astype("float64")

# %% [markdown]
# above / below certain C range expect tensile and yield strength (confidence %)
#
# within a range of

# %%
steel_df_sorted["Hardness (HB)"] = steel_df_sorted["Hardness (HB)"].astype("int64")

# %%
steel_df_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187 entries, 0 to 187
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SAE Grade             187 non-null    object
#  1   Conditions            187 non-null    object
#  2   UTS (Ksi)             187 non-null    int64
#  3   Yield Strength (PSI)  187 non-null    float64
#  4   Elongation (%)        187 non-null    float64
#  5   Reduction (%)         187 non-null    float64
#  6   Hardness (HB)         187 non-null    int64
#  7   C (Max)               187 non-null    float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 13.1+ KB

# %%
sns.pairplot(steel_df_sorted)
